# %%
pip install yfinance==0.2.40
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.5/939.5 kB 25.9 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 4.6 MB/s eta 0:00:00
# ...
#   Created wheel for peewee: filename=peewee-3.17.7-cp310-cp310-linux_x86_64.whl size=300449 sha256=7e156393dee5eaf1f990ebf382ee4b4a698e6d85d2caaca03bcf39f0d75c6141
#   Stored in directory: /root/.cache/pip/wheels/8d/0e/f8/48eb93a200fca4c502d7590613616fa4d2c9533f7308f9e28a
# Successfully built peewee
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from pandas_datareader.data import DataReader
import yfinance as yf

 
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")

# %%
asset_list = ['AAPL', 'NVDA', 'TSLA', 'AMZN',"CW8.PA",'BTC-USD','ETH-USD','SOL-USD','AAVE-USD']
asset_name = ["APPLE", "NVIDIA", "TESLA", "AMAZON","MSCI WORLD","BITCOIN","ETHEREUM","SOLANA","AAVE"]

end = datetime.now()
start = datetime(end.year - 5, end.month, end.day)
dataframes = []
for asset in asset_list:
    dataframes.append(yf.download(asset, start, end))
for i in range(len(dataframes)): 
    dataframes[i]["Asset_Name"] = asset_name[i]
# Afficher les données
 
df = pd.concat(dataframes, axis=0)
df.head(10)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close      Close       High        Low  \
# Ticker                          AAPL       AAPL       AAPL       AAPL
# Date
# 2019-10-21 00:00:00+00:00  58.182007  60.127499  60.247501  59.330002
# 2019-10-22 00:00:00+00:00  58.048962  59.990002  60.549999  59.904999
# ...

# %% [markdown]
# **PORTFOLIO CORRELATION 1**

# %%
# Extraire les prix de clôture et les pivoter pour obtenir un DataFrame avec les actifs en colonnes
price_data = df.pivot_table(index=df.index, columns='Asset_Name', values='Adj Close')

# Calculer la corrélation entre les actifs
correlation_matrix = price_data.corr()

# Afficher la matrice de corrélation
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matrice de Corrélation entre les Actifs')
plt.show()

# Corrélations entre actifs
correlation_matrix = price_data.corr()

# Masque de la partie supérieure de la matrice
upper_triangle_mask = np.triu(np.ones(correlation_matrix.shape), k=1)

# Appliquer le masque
masked_correlation = correlation_matrix * upper_triangle_mask

# Calculer la moyenne des valeurs absolues des corrélations
mean_absolute_correlation = masked_correlation.abs().mean().mean()

print("Moyenne des corrélations absolues :", mean_absolute_correlation)
# Out:
# Moyenne des corrélations absolues : 0.2606674365466868

# %% [markdown]
# **PORTFOLIO_2 CORRELATION**

# %%
asset_list = ['AAPL', 'NVDA', 'TSLA', 'AMZN','TTE','MC.PA',"CW8.PA",'BTC-USD','ETH-USD','SOL-USD','AAVE-USD']
asset_name = ["APPLE", "NVIDIA", "TESLA", "AMAZON","TOTAL","LVMH","MSCI WORLD","BITCOIN","ETHEREUM","SOLANA","AAVE"]

end = datetime.now()
start = datetime(end.year - 5, end.month, end.day)
dataframes = []
for asset in asset_list:
    dataframes.append(yf.download(asset, start, end))
for i in range(len(dataframes)): 
    dataframes[i]["Asset_Name"] = asset_name[i]
# Afficher les données
 
df = pd.concat(dataframes, axis=0)


# Extraire les prix de clôture et les pivoter pour obtenir un DataFrame avec les actifs en colonnes
price_data = df.pivot_table(index=df.index, columns='Asset_Name', values='Adj Close')

# Calculer la corrélation entre les actifs
correlation_matrix = price_data.corr()

# Afficher la matrice de corrélation
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matrice de Corrélation entre les Actifs')
plt.show()

# Corrélations entre actifs
correlation_matrix = price_data.corr()

# Masque de la partie supérieure de la matrice
upper_triangle_mask = np.triu(np.ones(correlation_matrix.shape), k=1)

# Appliquer le masque
masked_correlation = correlation_matrix * upper_triangle_mask

# Calculer la moyenne des valeurs absolues des corrélations
mean_absolute_correlation = masked_correlation.abs().mean().mean()

print("Moyenne des corrélations absolues :", mean_absolute_correlation)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Moyenne des corrélations absolues : 0.2616626011558389

# %% [markdown]
# **PORTFOLIO_3 CORRELATION**

# %%
asset_list = ['AAPL', 'TSLA','TTE','MC.PA',"CW8.PA",'BTC-USD','ETH-USD','AAVE-USD']
asset_name = ["APPLE", "TESLA","TOTAL","LVMH","MSCI WORLD","BITCOIN","ETHEREUM","AAVE"]

end = datetime.now()
start = datetime(end.year - 5, end.month, end.day)
dataframes = []
for asset in asset_list:
    dataframes.append(yf.download(asset, start, end))
for i in range(len(dataframes)): 
    dataframes[i]["Asset_Name"] = asset_name[i]
# Afficher les données
 
df = pd.concat(dataframes, axis=0)


# Extraire les prix de clôture et les pivoter pour obtenir un DataFrame avec les actifs en colonnes
price_data = df.pivot_table(index=df.index, columns='Asset_Name', values='Adj Close')

# Calculer la corrélation entre les actifs
correlation_matrix = price_data.corr()

# Afficher la matrice de corrélation
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matrice de Corrélation entre les Actifs')
plt.show()

# Corrélations entre actifs
correlation_matrix = price_data.corr()

# Masque de la partie supérieure de la matrice
upper_triangle_mask = np.triu(np.ones(correlation_matrix.shape), k=1)

# Appliquer le masque
masked_correlation = correlation_matrix * upper_triangle_mask

# Calculer la moyenne des valeurs absolues des corrélations
mean_absolute_correlation = masked_correlation.abs().mean().mean()

print("Moyenne des corrélations absolues :", mean_absolute_correlation)
asset_list = ['AAPL', 'TSLA','TTE','MC.PA',"CW8.PA",'BTC-USD','ETH-USD','AAVE-USD']
asset_name = ["APPLE", "TESLA","TOTAL","LVMH","MSCI WORLD","BITCOIN","ETHEREUM","AAVE"]
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Moyenne des corrélations absolues : 0.2682927920081873

# %%
asset_list = ['AAPL', 'NVDA', 'TSLA', 'AMZN','TTE','MC.PA',"CW8.PA",'BTC-USD','ETH-USD','SOL-USD','AAVE-USD']
asset_name = ["APPLE", "NVIDIA", "TESLA", "AMAZON","TOTAL","LVMH","MSCI WORLD","BITCOIN","ETHEREUM","SOLANA","AAVE"]

end = datetime.now()
start = datetime(end.year - 5, end.month, end.day)
dataframes = []
for asset in asset_list:
    dataframes.append(yf.download(asset, start, end))
for i in range(len(dataframes)): 
    dataframes[i]["Asset_Name"] = asset_name[i]
# Afficher les données
 
df = pd.concat(dataframes, axis=0)


# Extraire les prix de clôture et les pivoter pour obtenir un DataFrame avec les actifs en colonnes
price_data = df.pivot_table(index=df.index, columns='Asset_Name', values='Adj Close')

# Calculer la corrélation entre les actifs
correlation_matrix = price_data.corr()

asset_weights = np.array([0.023, 0.0056, 0.011, 0.0088, 0,0,0.666,0.187,0.07,0.017,0.0087])

numeric_price_data = price_data.select_dtypes(include=[np.number])


returns = numeric_price_data.pct_change(fill_method=None).dropna()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# **PORTFOLIO VOLATILITY**

# %%
cov_matrix = returns.cov()
portfolio_volatility = np.sqrt(np.dot(asset_weights.T, np.dot(cov_matrix, asset_weights)))
print(f"portfolio_volatility : {(portfolio_volatility*100).round(2)}%")
# Out:
# portfolio_volatility : 1.82%

# %% [markdown]
# **PORTFOLIO EXPECTED RETURNS USING MONTE CARLO SIMULATION**

# %%
mean_returns = returns.mean()  
volatility = portfolio_returns.std()   
num_simulations = 1000
days = 365


simulated_returns = np.random.multivariate_normal(mean_returns, cov_matrix, (days,num_simulations))
portfolio_returns = simulated_returns.dot(weights)

# Visualisation de la distribution des pertes simulées
plt.plot(np.cumsum(portfolio_returns,axis=0))
plt.title("Portfolio Returns using Monte Carlo Simulation")
plt.xlabel('Days')
plt.ylabel('Cumulative Returns')
plt.legend()
plt.show()

print(f"Expected Return : {portfolio_returns.mean()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 mean_returns = returns.mean()
#       2 volatility = portfolio_returns.std()
#       3 num_simulations = 1000
#
# NameError: name 'returns' is not defined

# %% [markdown]
# **VALUE AT RISK**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Paramètres
num_simulations = 10000 
S0 = 13000               # Valeur initiale du portefeuille
days = 10        

simulated_returns = np.random.multivariate_normal(mean_returns, cov_matrix, (days, num_simulations))

# Calcul de la valeur du portefeuille à chaque simulation (cumulatif sur les jours)
simulated_portfolio_values = S0 * np.exp(simulated_returns.sum(axis=0))

simulated_losses = S0 - simulated_portfolio_values

# Fusionner toutes les simulations en une seule série
simulated_losses_flat = simulated_losses.flatten()


confidence_level = 0.95

VaR_monte_carlo = np.percentile(simulated_losses, (1 - confidence_level) * 100)

print(f"VaR Monte Carlo sur {days} jours à {confidence_level*100}% : {VaR_monte_carlo.round(2)}")
# Tracer un histogramme avec une seule couleur
plt.hist(simulated_losses_flat, bins=50, alpha=0.75, color='blue')
plt.axvline(x=VaR_monte_carlo, color='red', linestyle='--', label=f'VaR à {confidence_level*100}%')
plt.title(f'Distribution des pertes simulées (Monte Carlo) sur {days} jours')
plt.xlabel('Pertes')
plt.ylabel('Fréquence')
plt.legend()
plt.show()
# Out:
# VaR Monte Carlo sur 10 jours à 95.0% : -3206.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from datetime import datetime, timedelta
from sklearn.linear_model import LinearRegression



from sklearn.ensemble import RandomForestRegressor
from keras.models import Sequential
from keras.layers import Dense, LSTM



# Dates de début et de fin
end = datetime.now()
start = datetime(end.year-5, end.month, end.day)
end_train = datetime(end.year -4 , end.month, end.day)

# Téléchargement des données
df = yf.download('AAPL', start, end)

# Création de nouvelles colonnes
df["Hier"] = df["Adj Close"].shift(1)
df["Avant-hier"] = df["Hier"].shift(1)
df["RA10"] = df["Adj Close"].rolling(10).mean()
df["RA30"] = df["Adj Close"].rolling(30).mean()
df["RA50"] = df["Adj Close"].rolling(50).mean()
df = df.dropna()

# Séparation des données d'entraînement et de test
df_train = df[:end_train]
df_test = df[end_train:end]

from sklearn.preprocessing import MinMaxScaler


y_train = df_train["Adj Close"]
X_train = df_train.drop(["Adj Close"], axis=1)

scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

# Séparer les caractéristiques et la cible
y_train = df_train["Adj Close"].values.reshape(-1, 1)  # Reshape pour le scaler
X_train = df_train.drop(["Adj Close"], axis=1).values

# Appliquer le scaler aux données d'entraînement
X_train = scaler_X.fit_transform(X_train)
y_train = scaler_y.fit_transform(y_train)


model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (X_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

model.fit(X_train, y_train, batch_size=10, epochs=10)

# Préparer les données de test
X_test = df_test.drop(["Adj Close"], axis=1)
X_test = scaler_X.transform(X_test)  # Transformer les données de test

# Reshape pour LSTM
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Faire des prédictions
y_hat = model.predict(X_test)
y_hat = scaler_y.inverse_transform(y_hat)


y_hat_train = model.predict(X_train)
y_hat_train = scaler_y.inverse_transform(y_hat_train)


# Visualisation des résultats 
plt.plot(df.index, df["Adj Close"], label="Prix réel")
plt.plot(df_test.index, df_test["Adj Close"], label="Prix réel test",color='red')
plt.plot(df_train.index, df_train["Adj Close"], label="Prix réel entrainement",color='orange')
plt.plot(df_train.index, y_hat_train, label="Prix prédit", color='black')  # Prédictions sur l'entraînement
plt.plot(df_test.index, y_hat,color='black')  # Prédictions sur le test
plt.xlabel("Date")
plt.ylabel("Prix de clôture (USD)")
plt.title("Prédictions du prix de clôture d'Apple")
plt.legend()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0897
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025
# Epoch 8/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018
# Epoch 9/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018
# Epoch 10/10
# ...
